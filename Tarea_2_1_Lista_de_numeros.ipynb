# %%
def sumar(lista):
    if len(lista)== 1:
        return lista[0]
    else:
        return lista[0] + sumar(lista[1:])

num = [1,2,3,4,5]
resultado = sumar(num)
print("La suma de valores es igual a ", resultado)
# Out:
# La suma de valores es igual a  15
