# %%
fibonacci_cache = {}
def fibonacci (n):
    if n == 0:
        return 0
    if n == 1:
        return 1
    if n > 1:
          return (fibonacci (n-1) + fibonacci (n-2))
    else:
        return (fibonacci (n-1) + fibonacci (n-2))

    
n = int(input('Fibonacci de: '))
print(fibonacci(n))
# Out:
# Fibonacci de: 7
# 13
